# %%
import pandas as pd

# %% [markdown]
# Données

# %%
df_red = pd.read_csv("winequality-red.csv", delimiter=";")
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# 1599 observation pour les vins rouges

# %%
df_white = pd.read_csv("winequality-white.csv", delimiter=";")
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# 4898 observations pour les vins blancs, on en réduit le nombre :

# %%
df_white = df_white.iloc[:1700]
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1695            7.2              0.21         0.33             3.0      0.036
# 1696            8.5              0.32         0.36            14.9      0.041
# 1697            6.9              0.18         0.30             2.0      0.038
# 1698            7.0              0.24         0.30             4.2      0.040
# 1699            6.3              0.26         0.29             2.2      0.043
#
# ...

# %%
df_test = pd.concat([df_white, df_red]).sample(frac=1).reset_index(drop=True)
df_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               6.6              0.80         0.03             7.8      0.079
# 1               6.4              0.18         0.35             1.0      0.045
# 2               6.5              0.46         0.14             2.4      0.114
# 3               6.4              0.22         0.34             1.8      0.057
# 4               7.2              0.23         0.39            14.2      0.058
# ...             ...               ...          ...             ...        ...
# 3294            8.8              0.61         0.19             4.0      0.094
# 3295            7.8              0.48         0.68             1.7      0.415
# 3296            8.4              0.31         0.29             3.1      0.194
# 3297            8.4              0.65         0.60             2.1      0.112
# 3298            7.8              0.24         0.18             6.7      0.046
#
# ...

# %%
def EM_algo(beta, stop = 1e-3):
    b = [beta]
    T = 0
    while ??? > stop:
        Q =
        pi_g =
        m_g =
        var_g =
        b.

# %%
c=0
while c<5:
    print(c)
    c+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a= 1e-3
a
# Out:
# 0.001

# %%
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
